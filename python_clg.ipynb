# %% [markdown]
# <a href="https://colab.research.google.com/github/sketchdelilah/python_py/blob/main/python_clg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***QUESTION 1***
# ------------------------------------------------------------------------------------------------------------------------------------------------
# # 1.input a string.
#
# # 2.capitalize, small case, camel case (first letter of each word is in capital letter) and output the string.
#
# # 3.concatinate with another string.
# (here " " is used to add space between both strings)
#
# # 4.print the number of characters in the string.
#
# # 5.extract the 4th character of the string.
#
# # 6.extract a substring of the string.
#
# # 7.split the string into two string and print both the strings.
#
# # 8.replace the leading and trailing whitespace to"*".
#
# # 9.replace all the occurance of "a" in the string to "f".
#
# # 10.remove all the even characters from the string.
#
# # 11.find the number of occurance of "a" in the string.
#
# # 12.return the index of "o" in the string.
#
# (before entering the first text use space and end with a !)
#
# (for second text end with a space)
#
# [they are used here to replace the space with *, that is for the 8th question)

# %%
string=input("Enter your text:")

print(string.upper())
print(string.lower())
print(string.title())

string1=input("Enter other text:")
string2=string+""+string1
print(string2)

print(len(string2))

print(string2[3])

print(string2[:5])

print(string2.split("!"))

print(string2.replace(" ","*"))

print(string2.replace("a","f"))

print(string2[::2])

print(string2.count("a"))

print(string2.find("o"))
# Out:
# Enter your text: Hello!
#  HELLO!
#  hello!
#  Hello!
# Enter other text:Vikas
#  Hello!Vikas
# 13
# l
#  Hell
# [' Hello', 'Vikas ']
# *Hello!Vikas*
#  Hello!Vikfs
#  el!ia
# 1
# 5

# %% [markdown]
# ## ***QUESTION2***
#
# # 1.input a list.
# (can't use "list" cuz its a keyword)
#
# (math is used since sqrt mentioned)
#
# # 2.sort the list.
#
# # 3.reverse the list.
#
# # 4.add an element to the list.
#
# # 5.remove an element from the list.
#
# # 6.remove an element by the position from the list.
#
# # 7.remove all elements from the list.
#
# # 8.return the number of elements in the list.
#
# # 9.extract all the digits of a number into list.
#
# # 10.convert a number into its binary number.
#
# # 11.return a list of all the square roots of the numbers in a list.
#
# # 12.copy a list.
#
# # 13.reverse a number without a built in function.
#
# # 14.insert an element into a specific position in a list.

# %%
import math
mylist=[12,22,23,4,45]

mylist.sort()
print(mylist)

mylist.reverse()
print(mylist)

mylist.append(17)
print(mylist)

mylist.remove(4)
print(mylist)

mylist.pop(4)
print(mylist)

mylist.clear()
print(mylist)

a=len(mylist)
print(a)

number=int(input("Enter a number:"))
digits=[]
while number>0:
  digits.append(number%10)
  number=number//10
digits.reverse()
print(digits)

num=int(input("Enter a number:"))
binary=""
while num>0:
  binary=str(num%2)+binary
  num=num//2
print(binary)

yourlist=[]
n=int(input("Enter the number of elements in the list:"))
for i in range(n):
  element=int(input("Enter the element:"))
  yourlist.append(element)
print(yourlist)
square_root=[math.sqrt(n) for n in yourlist]
print(square_root)

newlist=yourlist.copy()
print(newlist)

n=""
no=int(input("Enter a number:"))
while no>0:
  n= n + str(no%10)
  no=no//10
print(n)

abc=[12,23,34]
print(abc)
abc.insert(2,56)
print(abc)
# Out:
# [4, 12, 22, 23, 45]
# [45, 23, 22, 12, 4]
# [45, 23, 22, 12, 4, 17]
# [45, 23, 22, 12, 17]
# [45, 23, 22, 12]
# []
# 0
# Enter a number:234
# [2, 3, 4]
# Enter a number:50
# 110010
# Enter the number of elements in the list:4
# Enter the element:9
# Enter the element:16
# Enter the element:25
# Enter the element:36
# [9, 16, 25, 36]
# [3.0, 4.0, 5.0, 6.0]
# [9, 16, 25, 36]
# Enter a number:213
# 312
# [12, 23, 34]
# [12, 23, 56, 34]

# %% [markdown]
# # ***QUESTION3***
#
# # 1.input from user and create a dictionary.
#
# # 2.insert a key value into the dictionary.
#
# # 3.print the value of a user input key from the dictionary.
#
# # 4.delete a value from the dictionary.
#
# # 5.remove a key from a dictionary.
#
# # 6.remove all the values from the dictionary.
#
# # 7.return all the values only from the dictionary.
#
# # 8.update a key with another value.
#
# # 9.return all the keys only from the dictionary.
#
# # 10.merge two dictionaries
#
# # 11.swap two numbers.
#
# # 12.swap two numbers without a temporary variable.
#
# # 13.sort a dictionary.

# %%
dictionary=[]
n=int(input("Enter the number of elements in the dictionary:"))
